# %%
# Read mat file 
# !pip install mat4py

# %%
from mat4py import loadmat

data = loadmat('Dataset/training_dataset/training_data/annotations/Buffy_1.mat')

# %%
# for item in data['boxes']:
#     print(item['a'])
data
# Out:
# {'boxes': [{'a': [488.4295494212492, 345.6226103157693],
#    'b': [461.5704505787508, 348.3773896842307],
#    'c': [465.5704505787508, 387.3773896842307],
#    'd': [492.4295494212492, 384.6226103157693]},
#   {'a': [449.81237317998927, 397.2448898907434],
#    'b': [462.18762682001085, 426.75511010925646],
#    'c': [493.1876268200108, 413.7551101092565],
#    'd': [480.8123731799892, 384.2448898907435]}]}

# %%
# Show original image 
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('Dataset/training_dataset/training_data/images/Buffy_1.jpg')

plt.figure(figsize=(12, 12))
plt.imshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cv2
# {'boxes': [{'a': [488.4295494212492, 345.6226103157693],
#    'b': [461.5704505787508, 348.3773896842307],
#    'c': [465.5704505787508, 387.3773896842307],
#    'd': [492.4295494212492, 384.6226103157693]},
#   {'a': [449.81237317998927, 397.2448898907434],
#    'b': [462.18762682001085, 426.75511010925646],
#    'c': [493.1876268200108, 413.7551101092565],
#    'd': [480.8123731799892, 384.2448898907435]}]}
#-----------------------------------------------
# xmin = d2 ; xmax = b2 | ymin = a1 , ymax = c1 |
#-----------------------------------------------
# Show original image 
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('Dataset/training_dataset/training_data/images/Buffy_1.jpg')

# x_min, x_max, y_min, y_max = [384.6226103157693,348.3773896842307,488.4295494212492, 465.5704505787508]
x_min, x_max, y_min, y_max = [384.2448898907435,426.75511010925646,449.81237317998927, 493.1876268200108]
# x_min, y_min, w, h = bbox
# for i,bbox in enumerate(image_bbox):
#     x_min, y_min, w, h = bbox
#     x_min, x_max, y_min, y_max = int(x_min), int(x_min + w), int(y_min), int(y_min + h)
#     cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color=(255, 0, 0), thickness =4)
    
#     # Thêm label vào ảnh 
#     class_name = class_idx_name[category_id[i]] # lấy name label 
#     ((text_width, text_height), _) = cv2.getTextSize(class_name, cv2.FONT_HERSHEY_SIMPLEX, 0.35, 1)
#     cv2.rectangle(img, (x_min, y_min - int(1.3 * text_height)), (x_min + text_width, y_min),  (255, 0,0) , -1)
#     cv2.putText(img, class_name, (x_min, y_min - int(0.3 * text_height)), cv2.FONT_HERSHEY_SIMPLEX, 0.35,(255, 255, 255), lineType=cv2.LINE_AA)
# x_min, x_max, y_min, y_max = int(x_min), int(x_min + w), int(y_min), int(y_min + h)
cv2.rectangle(img, (int(x_min), int(y_min)), (int(x_max), int(y_max)), color=(255, 0, 0), thickness =4)

plt.figure(figsize=(12, 12))
plt.imshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib
