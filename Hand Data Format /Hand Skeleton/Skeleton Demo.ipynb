# %%
import os
import os.path
import numpy as np
import json
import matplotlib
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20,20)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # Train

# %%
jsonPath_train = "/home/razer/Desktop/hand143_panopticdb/annotations/train.json"

with open(jsonPath_train, 'r') as fid:
    data_train = json.load(fid)

# %%
folder = "/home/razer/Desktop/hand143_panopticdb/"

# %%
edges = [[0,1],[1,2],[2,3],[3,4],[0,5],[5,6],[6,7],[7,8],[0,9],[9,10],[10,11],[11,12],[0,13],[13,14],[14,15],[15,16],[0,17],[17,18],[18,19],[19,20]]
for num_item in data_train:
    
    # Read file and Point in Skeleton
    image_path = data_train[num_item]['img_paths']
    print(image_path)
    new_point_list = [[point[0],point[1]] for point in data_train[num_item]['joint_self']]
    print(new_point_list)
    
    # Plot image and point 
    im = plt.imread(folder+image_path)
#     [(plt.plot(point[0],point[1] ,'r.'),plt.text(point[0],point[1],'{0}'.format(i))) for i,point in enumerate(new_point_list)]
    [plt.plot(point[0],point[1] ,'r.') for point in new_point_list]

    # Plot skeleton
#     rgb = 
#     plt.plot(pts[e,0],pts[e,1],color=rgb)
    [plt.plot((new_point_list[index[0]][0],new_point_list[index[1]][0]),(new_point_list[index[0]][1],new_point_list[index[1]][1]) ,\
              color=matplotlib.colors.hsv_to_rgb([ie/float(len(edges)),1.0,1.0])) for ie, index in enumerate(edges)] 
    
    plt.imshow(im)
    
    break
# Out:
# imgs/00000000.jpg
# [[562.27, 461.291], [572.745, 451.27], [588.074, 435.816], [599.621, 421.758], [610.89, 411.891], [585.573, 408.807], [594.483, 385.657], [602.064, 370.899], [609.337, 357.815], [577.952, 406.056], [587.035, 380.369], [592.803, 364.323], [598.283, 349.194], [570.158, 407.455], [578.575, 383.715], [584.22, 369.874], [589.842, 356.602], [561.127, 412.249], [564.387, 393.267], [566.21, 382.667], [568.584, 372.46]]

# %%
new_point_list
# Out:
# [[562.27, 461.291],
#  [572.745, 451.27],
#  [588.074, 435.816],
#  [599.621, 421.758],
#  [610.89, 411.891],
#  [585.573, 408.807],
#  [594.483, 385.657],
#  [602.064, 370.899],
#  [609.337, 357.815],
#  [577.952, 406.056],
#  [587.035, 380.369],
#  [592.803, 364.323],
#  [598.283, 349.194],
#  [570.158, 407.455],
#  [578.575, 383.715],
#  [584.22, 369.874],
#  [589.842, 356.602],
#  [561.127, 412.249],
#  [564.387, 393.267],
#  [566.21, 382.667],
#  [568.584, 372.46]]

# %%
# Các giá trị trong edges là các giá trị index của 1 tọa độ point trong list 
for index in edges: 
    point1 = new_point_list[index[0]]
    point2 = new_point_list[index[1]] 
    print(point1[])
    break
# Out:
# [562.27, 461.291]
